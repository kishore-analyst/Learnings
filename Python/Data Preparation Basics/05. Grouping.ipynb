# %% [markdown]
# ## grouping data by column index

# %%
import numpy as np
import pandas as pd

from pandas import Series, DataFrame

# %%
address = r"D:\[07] Technical Tools\Python\Learing\LinkedIn Course\02. Python for Data Science and Machine Learning part-01\Resource files\Data\mtcars.csv"

# %%
cars = pd.read_csv(address)

# %%
cars.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
cars.columns.values[0] = 'car_name'

# %%
cars.head()
# Out:
#             car_name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
cyl_grp = cars.groupby(cars['cyl'])
cyl_grp.mean(numeric_only = True)
# Out:
#      car_name        mpg        disp          hp      drat        wt  \
# cyl
# 4         NaN  26.663636  105.136364   82.636364  4.070909  2.285727
# 6         NaN  19.742857  183.314286  122.285714  3.585714  3.117143
# 8         NaN  15.100000  353.100000  209.214286  3.229286  3.999214
#
#           qsec        vs        am      gear      carb
# cyl
# 4    19.137273  0.909091  0.727273  4.090909  1.545455
# 6    17.977143  0.571429  0.428571  3.857143  3.428571
# 8    16.772143  0.000000  0.142857  3.285714  3.500000

# %%
cyl_grp
